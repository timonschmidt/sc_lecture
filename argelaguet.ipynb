# %% [markdown]
# # Data: Argelaguet et al.
#
# In this notebook, we combine the count table with the meta data and filter for embryonic day 5,5.

# %%
import scanpy as sc
import anndata
# Out:
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/matplotlib/__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/scanpy/tools/_louvain.py:17: DeprecationWarning: This package has been superseded by the `leidenalg` package and will no longer be maintained. Please upgrade to the `leidenalg` package.
#   from louvain.VertexPartition import MutableVertexPartition

# %%
meta_argelaguet = sc.read_text('../data/rnaseq_mouse_e55/Argelaguet_meta.txt', dtype="str", delimiter="\t")
adata_argelaguet = sc.read_text("../data/rnaseq_mouse_e55/Argelaguet_counts.txt").T
print(meta_argelaguet)
print(adata_argelaguet)
# Out:
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 874 × 13
# AnnData object with n_obs × n_vars = 1033 × 22084

# %%
print(meta_argelaguet.to_df()["day"].unique())
print(meta_argelaguet.to_df()["day2"].unique())
# Out:
# ['Day5' 'Day7' 'Day6' 'Day4' 'Day2']
# ['Day4-5' 'Day6-7' 'Day2']

# %%
adata_argelaguet.to_df()
# Out:
#                                                     ENSMUSG00000051951  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000025900  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 6.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000025902  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000033845  \
# A02                                                              653.0
# A03                                                              246.0
# A04                                                              297.0
# A05                                                              464.0
# A06                                                              277.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...               123.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...               110.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...               119.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...               146.0
#
#                                                     ENSMUSG00000025903  \
# A02                                                              481.0
# A03                                                              261.0
# A04                                                              181.0
# A05                                                              118.0
# A06                                                              320.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                13.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 3.0
#
#                                                     ENSMUSG00000104217  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000033813  \
# A02                                                              513.0
# A03                                                              670.0
# A04                                                              269.0
# A05                                                              180.0
# A06                                                              103.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                77.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                27.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                77.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                75.0
#
#                                                     ENSMUSG00000002459  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 1.0
#
#                                                     ENSMUSG00000033793  \
# A02                                                              405.0
# A03                                                              941.0
# A04                                                              190.0
# A05                                                              148.0
# A06                                                              157.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                54.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...               132.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                73.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...               178.0
#
#                                                     ENSMUSG00000025905  ...  \
# A02                                                                0.0  ...
# A03                                                                0.0  ...
# A04                                                                0.0  ...
# A05                                                                0.0  ...
# A06                                                                0.0  ...
# ...                                                                ...  ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0  ...
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 2.0  ...
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0  ...
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0  ...
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                44.0  ...
#
#                                                     ENSMUSG00000079192  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000079794  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000094799  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000095019  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000094915  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000079808  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000095041  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000063897  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000096730  \
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
#                                                     ENSMUSG00000095742
# A02                                                                0.0
# A03                                                                0.0
# A04                                                                0.0
# A05                                                                0.0
# A06                                                                0.0
# ...                                                                ...
# lane6819_TGCAGCTA_TATCCTCT_Plate8_B11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TCGACTAG_Plate10_A11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_v...                 0.0
# lane6819_TGCAGCTA_TTATGCGA_Plate10_H11_L001_R1_...                 0.0
# lane6819_TGCAGCTA_TTCTAGCT_Plate10_B11_L001_R1_...                 0.0
#
# [1033 rows x 22084 columns]

# %%
list((set(adata_argelaguet.obs_names) - set(meta_argelaguet.to_df()["id_rna"].values)))
# Out:
# ['G03',
#  'lane6819_ATCTCAGG_TTATGCGA_Plate9_H12_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'A09',
#  'Plate1_F02',
#  'G06',
#  'lane6819_TGCAGCTA_TCTCTCCG_Plate8_H11_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'Plate1_E03',
#  'Plate1_H07',
#  'lane6819_CGTACTAG_CTCTCTAT_Plate7_A02_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'G02',
#  'Plate1_E11',
#  'A04',
#  'Plate1_E05',
#  'lane6819_CGAGGCTG_CTCTCTAT_Plate7_A08_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_GCTCATGA_TATCCTCT_Plate7_B11_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'H03',
#  'Plate1_G06',
#  'H11',
#  'Plate2_F12',
#  'lane6819_AAGAGGCA_TCTCTCCG_Plate7_H09_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'A05',
#  'lane6819_TCGACGTC_TTATGCGA_Plate10_H12_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_AAGAGGCA_CTCTCTAT_Plate7_A09_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'Plate2_F02',
#  'Plate1_D11',
#  'lane6819_TAAGGCGA_TTATGCGA_Plate9_H01_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_CGTACTAG_TCTCTCCG_Plate7_H02_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'F09',
#  'lane6819_CTCTCTAC_CGTCTAAT_Plate7_G07_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_GCGTAGTA_TCTCTCCG_Plate8_H03_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'B02',
#  'D04',
#  'E01',
#  'lane6819_TCCTGAGC_CGTCTAAT_Plate7_G04_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'Plate1_E07',
#  'lane6819_TAGGCATG_TCTCTCCG_Plate7_H06_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'Plate1_D10',
#  'C02',
#  'G07',
#  'A03',
#  'lane6819_CGATCAGT_AAGGAGTA_Plate8_E10_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'D09',
#  'H07',
#  'E12',
#  'Plate1_D07',
#  'lane6819_ATCTCAGG_TCTCTCCG_Plate7_H12_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'Plate1_G07',
#  'B01',
#  'C10',
#  'Plate1_E12',
#  'H10',
#  'H05',
#  'B12',
#  'D12',
#  'H06',
#  'lane6819_CGTACTAG_CTAAGCCT_Plate7_F02_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'F08',
#  'B07',
#  'B09',
#  'F10',
#  'H08',
#  'lane6819_CGATCAGT_CTCTCTAT_Plate8_A10_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'Plate1_H02',
#  'lane6819_CGTACTAG_TATCCTCT_Plate7_B02_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'B03',
#  'E02',
#  'Plate1_G08',
#  'F04',
#  'Plate1_D08',
#  'Plate1_E08',
#  'E07',
#  'lane6819_TACGCTGC_CTCTCTAT_Plate8_A05_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_TAGCGCTC_CTCTCTAT_Plate8_A07_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'C06',
#  'C12',
#  'A02',
#  'H02',
#  'E03',
#  'C09',
#  'C08',
#  'lane6819_CGATCAGT_CTAAGCCT_Plate8_F10_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_CCTAAGAC_AAGGAGTA_Plate8_E09_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'C03',
#  'C01',
#  'Plate1_F06',
#  'A08',
#  'Plate2_G07',
#  'G10',
#  'Plate2_G12',
#  'Plate1_E02',
#  'Plate1_F07',
#  'B08',
#  'E10',
#  'Plate1_D03',
#  'Plate1_D09',
#  'E11',
#  'lane6819_ATCTCAGG_CGTCTAAT_Plate7_G12_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'D01',
#  'E06',
#  'Plate1_G01',
#  'lane6819_ACTGAGCG_TCTCTCCG_Plate8_H08_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_CGTACTAG_AAGGAGTA_Plate7_E02_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'F03',
#  'Plate1_H06',
#  'B10',
#  'Plate1_F09',
#  'F02',
#  'F06',
#  'Plate1_G12',
#  'D06',
#  'C11',
#  'F11',
#  'E08',
#  'Plate1_F08',
#  'Plate1_G02',
#  'G11',
#  'D03',
#  'lane6819_CCTAAGAC_CGTCTAAT_Plate8_G09_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'E04',
#  'G09',
#  'lane6819_AGGCAGAA_TCTCTCCG_Plate7_H03_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_TCGACGTC_TCTCTCCG_Plate8_H12_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'A06',
#  'Plate1_F01',
#  'H09',
#  'Plate2_G05',
#  'D07',
#  'lane6819_GCTCATGA_GTAAGGAG_Plate7_C11_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'G01',
#  'lane6819_ATGCGCAG_TCTCTCCG_Plate8_H06_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'B05',
#  'lane6819_ATGCGCAG_TTATGCGA_Plate10_H06_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'F12',
#  'E09',
#  'F07',
#  'Plate1_H05',
#  'Plate1_F03',
#  'Plate1_E01',
#  'lane6819_ACTCGCTA_CTCTCTAT_Plate8_A01_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'D05',
#  'C04',
#  'D08',
#  'F05',
#  'Plate1_G04',
#  'D10',
#  'C05',
#  'Plate1_G09',
#  'Plate1_H09',
#  'Plate1_G03',
#  'Plate1_D12',
#  'lane6819_GGACTCCT_TCTCTCCG_Plate7_H05_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'C07',
#  'D11',
#  'H04',
#  'G12',
#  'A10',
#  'E05',
#  'B11',
#  'G08',
#  'B06',
#  'A07',
#  'G05',
#  'Plate1_D01',
#  'lane6819_TAAGGCGA_CTCTCTAT_Plate7_A01_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'Plate1_D02',
#  'lane6819_TAAGGCGA_TATCCTCT_Plate7_B01_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'lane6819_TACGCTGC_TCTCTCCG_Plate8_H05_L001_R1_val_1_GRCm38_ERCC_hisat2',
#  'Plate2_B12',
#  'Plate1_F12']
