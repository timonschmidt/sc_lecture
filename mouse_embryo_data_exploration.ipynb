# %%
import scanpy as sc
import anndata
# Out:
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/matplotlib/__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/scanpy/tools/_louvain.py:17: DeprecationWarning: This package has been superseded by the `leidenalg` package and will no longer be maintained. Please upgrade to the `leidenalg` package.
#   from louvain.VertexPartition import MutableVertexPartition

# %%
meta_cheng = sc.read_csv('../data/rnaseq_mouse_e55/Meta.CellRep_cheng2019.csv', delimiter=";", dtype="str")
meta_arge = sc.read_text('../data/rnaseq_mouse_e55/Argelaguet_meta.txt', dtype="str", first_column_names=True, delimiter="\t")
print(meta_cheng)
print(meta_arge)
# Out:
# AnnData object with n_obs × n_vars = 1724 × 4
# AnnData object with n_obs × n_vars = 874 × 13
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata_nowo = sc.read("../data/rnaseq_mouse_e55/Nowotschin_E55.h5ad")
adata_thow = sc.read("../data/rnaseq_mouse_e55/Thowfeequ_E55_norm_annotated_filtered.h5ad")
adata_cheng = sc.read_text("../data/rnaseq_mouse_e55/Cheng_raw_counts.txt")
adata_arge = sc.read_text("../data/rnaseq_mouse_e55/Argelaguet_counts.txt")
# Out:
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/anndata/_io/specs/methods.py:584: OldFormatWarning: Element '/obs/__categories/Cluster' was written without encoding metadata.
#   categories = read_elem(categories_dset)
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/anndata/_io/specs/methods.py:587: OldFormatWarning: Element '/obs/Cluster' was written without encoding metadata.
#   read_elem(dataset), categories, ordered=ordered
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/anndata/_io/specs/methods.py:584: OldFormatWarning: Element '/obs/__categories/Timepoint' was written without encoding metadata.
#   categories = read_elem(categories_dset)
# /home/ubuntu/miniconda3/envs/sc_data_integration/lib/python3.10/site-packages/anndata/_io/specs/methods.py:587: OldFormatWarning: Element '/obs/Timepoint' was written without encoding metadata.
#   read_elem(dataset), categories, ordered=ordered
# ...

# %%
print(adata_nowo)
print(adata_thow)
print(adata_cheng)
# Out:
# AnnData object with n_obs × n_vars = 11550 × 20897
#     obs: 'Cluster', 'Timepoint', 'CellType'
# AnnData object with n_obs × n_vars = 252 × 54737
#     obs: 'Run lane', 'Cell#', 'Stage', 'gene count', 'gene count rpm', 'fraction mapped', 'fraction mito', 'fraction spike-in', 'total reads (log10)', 'clusters', 'clusters_new', 'clusters_anno'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg'
# AnnData object with n_obs × n_vars = 18126 × 1724

# %%
adata_cheng.to_df()
# Out:
#                                         EB_130  EB_132  EB_131  EB_137  \
# Adora1                                    52.0     0.0     0.0     0.0
# Prim2                                    142.0    23.0   190.0     5.0
# Bai3                                       0.0     0.0     0.0     0.0
# Cflar                                     11.0    11.0     0.0     0.0
# Gpr39                                      0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# ERCC_0.45776367:mix1_0.91552734:mix2       0.0     0.0     0.0     0.0
# ERCC_0.22888184:mix1_0.45776367:mix2.1     0.0     0.0     0.0     0.0
# ERCC_0.22888184:mix1_0.45776367:mix2.2     0.0     0.0     0.0     0.0
# ERCC_0.11444092:mix1_0.22888184:mix2       0.0     0.0     0.0     0.0
# ERCC_0.05722046:mix1_0.11444092:mix2       0.0     0.0     0.0     0.0
#
#                                         EB_133  EB_134  EB_139  EB_140  \
# ...

# %%
adata_cheng.to_df()
# Out:
#                                         EB_130  EB_132  EB_131  EB_137  \
# Adora1                                    52.0     0.0     0.0     0.0
# Prim2                                    142.0    23.0   190.0     5.0
# Bai3                                       0.0     0.0     0.0     0.0
# Cflar                                     11.0    11.0     0.0     0.0
# Gpr39                                      0.0     0.0     0.0     0.0
# ...                                        ...     ...     ...     ...
# ERCC_0.45776367:mix1_0.91552734:mix2       0.0     0.0     0.0     0.0
# ERCC_0.22888184:mix1_0.45776367:mix2.1     0.0     0.0     0.0     0.0
# ERCC_0.22888184:mix1_0.45776367:mix2.2     0.0     0.0     0.0     0.0
# ERCC_0.11444092:mix1_0.22888184:mix2       0.0     0.0     0.0     0.0
# ERCC_0.05722046:mix1_0.11444092:mix2       0.0     0.0     0.0     0.0
#
#                                         EB_133  EB_134  EB_139  EB_140  \
# ...

# %%
meta_arge.to_df()
# Out:
#                                                        id_rna  \
# plate1_E01  lane6616_ACTCGCTA_AAGGAGTA_Tet_plate1_E01_L001...
# plate2_F01  lane6616_ACTCGCTA_AAGGCTAT_Tet_plate2_F01_L001...
# plate1_D01  lane6616_ACTCGCTA_ACTGCATA_Tet_plate1_D01_L001...
# plate2_C01  lane6616_ACTCGCTA_CCTAGAGT_Tet_plate2_C01_L001...
# plate1_G01  lane6616_ACTCGCTA_CGTCTAAT_Tet_plate1_G01_L001...
# ...                                                       ...
# Plate1_F10  lane6616_CGATCAGT_CTAAGCCT_Tet_Tet_plate1_F10_...
# Plate9_C02  lane6819_CGTACTAG_CCTAGAGT_Plate9_C02_L001_R1_...
# Plate9_E07  lane6819_CTCTCTAC_CTATTAAG_Plate9_E07_L001_R1_...
# Plate9_H01  lane6819_CTCTCTAC_CTATTAAG_Plate9_H01_L001_R1_...
# Plate9_H12  lane6819_CTCTCTAC_CTATTAAG_Plate9_H12_L001_R1_...
#
#                                   id_met                        id_acc   day  \
# plate1_E01  TET_embryoid_body_Plate1_E01  TET_embryoid_body_Plate1_E01  Day5
# ...
